# %%
print("hello")
# Out:
# hello

# %%
print(1)
# Out:
# 1

# %%
print(10+20)
# Out:
# 30

# %%
a=10
print(a)
# Out:
# 10

# %%
a=10
name="john"
num=5.32
print(a)
print(name)
print(num)
print(type(a))
print(type(name))
print(type(num))
# Out:
# 10
# john
# 5.32
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
python="true"
java="false"
print(python)
print(java)
print(type(python))
print(type(java))
# Out:
# true
# false
# <class 'str'>
# <class 'str'>

# %%
a=10
b=10
c=10
print(a)
print(b)
print(c)
# Out:
# 10
# 10
# 10

# %%
a=b=c=10
print(a)
print(b)
print(c)
# Out:
# 10
# 10
# 10

# %%
a="tomato"
b="onion"
c="cabbage"
print(a)
print(b)
print(c)
# Out:
# tomato
# onion
# cabbage

# %%
a,b,c="tomato","onion","cabbage"
print(a)
print(b)
print(c)
# Out:
# tomato
# onion
# cabbage

# %%
a=10
b=5
c=a+b
print(c)
# Out:
# 15

# %%
a=10
b=5
c=a-b
print(c)
# Out:
# 5

# %%
a=10
b=5
c=a*b
print(c)
# Out:
# 50

# %%
a=10
b=5
c=a/b
print(c)
# Out:
# 2.0

# %%
a=10
b=3
c=a|b
print(c)
# Out:
# 11

# %%
c=2**2
print(c)
# Out:
# 4

# %%
x=10
x+=4
print(x)
# Out:
# 14

# %%
x=10
x-=4
print(x)
# Out:
# 6

# %%
x=10
x*=4
print(x)
# Out:
# 40

# %%
x=10
x/=4
print(x)
# Out:
# 2.5

# %%
x=10
x%=4
print(x)
# Out:
# 2

# %%
x=10
x**4
print(x)
# Out:
# 10

# %%
a=10
print(a==10 and a<15)
# Out:
# True

# %%
a=10
print(a==10 or a<15)
# Out:
# True

# %%
a=10
print(not(a==10))
# Out:
# False

# %%
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
a=123.456
print(type(a))
# Out:
# <class 'float'>

# %%
x=2.5+20j
print(type(a))
print(x.real)
print(x.imag)
# Out:
# <class 'float'>
# 2.5
# 20.0

# %%
b=True
print(type(b))
# Out:
# <class 'bool'>

# %%
s='computer'
print(type(s))
# Out:
# <class 'str'>

# %%
x=[10,20,30,40]
b=bytes(x)
print(type(b))
# Out:
# <class 'bytes'>

# %%
x=[10,20,30,40]
b=bytearray(x)
print(type(b))
b[0]=12
print(b)
# Out:
# <class 'bytearray'>
# bytearray(b'\x0c\x14\x1e(')
